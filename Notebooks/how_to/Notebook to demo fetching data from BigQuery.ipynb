# %% [markdown]
# ### Imports

# %%
import os
os.chdir("../..")

# %%
import google.cloud.bigquery as bq
from src.bigquery.functions import (
    bq_query,
    bq_persist,
)

# %% [markdown]
# # Using BigQuery with python
#
# ### Fetching from BigQuery
#
# Define query

# %%
query = """
SELECT 
    *
FROM `gamesys-eu-dev-sbtech-data.sb_tech_presentation.BetSnapshot` 
WHERE lastSettlementDate = "2023-01-15"
LIMIT 100
"""

# %% [markdown]
# Use BigQuery function to make call.

# %%
bq_output_df = bq_query(query)
bq_output_df.head(5)
# Out:
# c:\Users\james.lai\OneDrive - AnzoGroup\Documents\code\personal_repo\.venv\Lib\site-packages\google\auth\_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#                 betID       purchaseBetID  relatedToBetID    userID
# 0  638093850173664304  638093850173664303            <NA>  35832625  \
# 1  638093823984491074  638093823984491073            <NA>  33702861
# 2  638093438595094273  638093438595094272            <NA>  35735650
# 3  638094066029313952  638094066029313951            <NA>  31699306
# 4  638093876027429300  638093876027429299            <NA>  34507924
#
#            domain    provider currencyCode  employeeID
# ...

# %% [markdown]
# ### Persisting to BigQuery
#
# Filter dataframe to not include columns with dict structures. For simplicity, filtering for a df with only the betID column
# NB: this step needed as having difficulty persisting columns with nested data

# %%
bq_output_to_persis_df = bq_output_df[['betID']]

# %% [markdown]
# Persist data to bq_persist

# %%
bq_persist(
    input_df = bq_output_to_persis_df, 
    table_name = 'JamesL.test_table',
    if_exists = 'replace'
)
# Out:
# c:\Users\james.lai\OneDrive - AnzoGroup\Documents\code\personal_repo\.venv\Lib\site-packages\google\auth\_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# Dataframe persisted
